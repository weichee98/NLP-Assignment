# %% [markdown]
# # YELP REVIEW

# %%
import pandas as pd
import nltk
import re
from nltk.tokenize import word_tokenize

# %%
data = pd.read_csv("Dataset/Yelp Review.csv")
data = data[["text"]]
data.rename(columns={'text':'Reviews'}, inplace=True)
data.head()
# Out:
#                                              Reviews
# 0  I was not expecting this concert to be as much...
# 1  brought mama for a belated birthday present. v...
# 2  I attended this show last night and was under ...
# 3  My husband got us tickets and I could not beli...
# 4  J. Lo was phenomenal!! Such a great show! She ...

# %%
data["Tokens"] = data["Reviews"].apply(word_tokenize)
data.head()
# Out:
#                                              Reviews  \
# 0  I was not expecting this concert to be as much...
# 1  brought mama for a belated birthday present. v...
# 2  I attended this show last night and was under ...
# 3  My husband got us tickets and I could not beli...
# 4  J. Lo was phenomenal!! Such a great show! She ...
#
#                                               Tokens
# 0  [I, was, not, expecting, this, concert, to, be...
# 1  [brought, mama, for, a, belated, birthday, pre...
# 2  [I, attended, this, show, last, night, and, wa...
# 3  [My, husband, got, us, tickets, and, I, could,...
# 4  [J, ., Lo, was, phenomenal, !, !, Such, a, gre...

# %%
data["POS Tagging"] = data["Tokens"].apply(nltk.pos_tag)
data.head()
# Out:
#                                              Reviews  \
# 0  I was not expecting this concert to be as much...
# 1  brought mama for a belated birthday present. v...
# 2  I attended this show last night and was under ...
# 3  My husband got us tickets and I could not beli...
# 4  J. Lo was phenomenal!! Such a great show! She ...
#
#                                               Tokens  \
# 0  [I, was, not, expecting, this, concert, to, be...
# 1  [brought, mama, for, a, belated, birthday, pre...
# 2  [I, attended, this, show, last, night, and, wa...
# 3  [My, husband, got, us, tickets, and, I, could,...
# 4  [J, ., Lo, was, phenomenal, !, !, Such, a, gre...
#
#                                          POS Tagging
# 0  [(I, PRP), (was, VBD), (not, RB), (expecting, ...
# 1  [(brought, JJ), (mama, NN), (for, IN), (a, DT)...
# 2  [(I, PRP), (attended, VBD), (this, DT), (show,...
# 3  [(My, PRP$), (husband, NN), (got, VBD), (us, P...
# 4  [(J, NNP), (., .), (Lo, NNP), (was, VBD), (phe...

# %%
def filter(x, tag):
    ans = set()
    
    for el in x:
        if el[1].startswith(tag):
            ans.add(el)
            
    return list(ans)

data["Nouns"] = data["POS Tagging"].apply(filter, args=("NN",))
data["Adjectives"] = data["POS Tagging"].apply(filter, args=("JJ",))

data.head()
# Out:
#                                              Reviews  \
# 0  I was not expecting this concert to be as much...
# 1  brought mama for a belated birthday present. v...
# 2  I attended this show last night and was under ...
# 3  My husband got us tickets and I could not beli...
# 4  J. Lo was phenomenal!! Such a great show! She ...
#
#                                               Tokens  \
# 0  [I, was, not, expecting, this, concert, to, be...
# 1  [brought, mama, for, a, belated, birthday, pre...
# 2  [I, attended, this, show, last, night, and, wa...
# 3  [My, husband, got, us, tickets, and, I, could,...
# 4  [J, ., Lo, was, phenomenal, !, !, Such, a, gre...
#
#                                          POS Tagging  \
# 0  [(I, PRP), (was, VBD), (not, RB), (expecting, ...
# 1  [(brought, JJ), (mama, NN), (for, IN), (a, DT)...
# 2  [(I, PRP), (attended, VBD), (this, DT), (show,...
# 3  [(My, PRP$), (husband, NN), (got, VBD), (us, P...
# 4  [(J, NNP), (., .), (Lo, NNP), (was, VBD), (phe...
#
#                                                Nouns  \
# 0  [(Versace, NNP), (daaaays, NNS), (performance,...
# 1  [(mama, NN), (costume, NN), (JLo, NNP), (prese...
# 2  [(etc, NN), (music, NN), (beware, NN), (straw,...
# 3  [(...., NNP), (stage, NN), (.The, NNP), (omg, ...
# 4  [(Lo, NNP), (energy, NN), (seats, NNS), (hits,...
#
#                                           Adjectives
# 0  [(moves-, JJ), (couple, JJ), (beautiful, JJ), ...
# 1  [(little, JJ), (overall, JJ), (new, JJ), (ligh...
# 2  [(few, JJ), (first, JJ), (longer, JJR), (nice,...
# 3  [(right, JJ), (high, JJ), (multiple, JJ), (ama...
# 4  [(phenomenal, JJ), (musical, JJ), (Such, JJ), ...

# %%
def combination(x,y):
    lst = []
    for i in range(len(x)):
        for j in range(len(y)):
            lst.append((re.sub(r'[^A-Za-z]', '', x[i][0].lower()),re.sub(r'[^A-Za-z]', '', y[j][0].lower())))
            
    return lst

data["Pairs"] = data.apply(lambda x: combination(x["Nouns"], x["Adjectives"]), axis=1)

data.head()
# Out:
#                                              Reviews  \
# 0  I was not expecting this concert to be as much...
# 1  brought mama for a belated birthday present. v...
# 2  I attended this show last night and was under ...
# 3  My husband got us tickets and I could not beli...
# 4  J. Lo was phenomenal!! Such a great show! She ...
#
#                                               Tokens  \
# 0  [I, was, not, expecting, this, concert, to, be...
# 1  [brought, mama, for, a, belated, birthday, pre...
# 2  [I, attended, this, show, last, night, and, wa...
# 3  [My, husband, got, us, tickets, and, I, could,...
# 4  [J, ., Lo, was, phenomenal, !, !, Such, a, gre...
#
#                                          POS Tagging  \
# 0  [(I, PRP), (was, VBD), (not, RB), (expecting, ...
# 1  [(brought, JJ), (mama, NN), (for, IN), (a, DT)...
# 2  [(I, PRP), (attended, VBD), (this, DT), (show,...
# 3  [(My, PRP$), (husband, NN), (got, VBD), (us, P...
# 4  [(J, NNP), (., .), (Lo, NNP), (was, VBD), (phe...
#
#                                                Nouns  \
# 0  [(Versace, NNP), (daaaays, NNS), (performance,...
# 1  [(mama, NN), (costume, NN), (JLo, NNP), (prese...
# 2  [(etc, NN), (music, NN), (beware, NN), (straw,...
# 3  [(...., NNP), (stage, NN), (.The, NNP), (omg, ...
# 4  [(Lo, NNP), (energy, NN), (seats, NNS), (hits,...
#
#                                           Adjectives  \
# 0  [(moves-, JJ), (couple, JJ), (beautiful, JJ), ...
# 1  [(little, JJ), (overall, JJ), (new, JJ), (ligh...
# 2  [(few, JJ), (first, JJ), (longer, JJR), (nice,...
# 3  [(right, JJ), (high, JJ), (multiple, JJ), (ama...
# 4  [(phenomenal, JJ), (musical, JJ), (Such, JJ), ...
#
#                                                Pairs
# 0  [(versace, moves), (versace, couple), (versace...
# 1  [(mama, little), (mama, overall), (mama, new),...
# 2  [(etc, few), (etc, first), (etc, longer), (etc...
# 3  [(, right), (, high), (, multiple), (, amazing...
# 4  [(lo, phenomenal), (lo, musical), (lo, such), ...

# %%
temp = data["Pairs"].tolist()
pairs_list = []

for lst in temp:
    pairs_list.extend(lst)

pairs_list
# Out:
# [('versace', 'moves'),
#  ('versace', 'couple'),
#  ('versace', 'beautiful'),
#  ('versace', 'live'),
#  ('versace', 'voice'),
#  ('versace', 'different'),
#  ('versace', 'too'),
#  ('versace', 'rican'),
#  ('versace', 'gotten'),
#  ('versace', 'colorful'),
#  ('versace', 'impressed'),
#  ('versace', 'worth'),
#  ('versace', 'magical'),
#  ('versace', 'chronological'),
#  ('versace', 'entire'),
#  ('versace', 'great'),
#  ('versace', 'energetic'),
#  ('versace', 'mobile'),
#  ('versace', 'much'),
#  ('versace', 'sexy'),
#  ('daaaays', 'moves'),
#  ('daaaays', 'couple'),
#  ('daaaays', 'beautiful'),
#  ('daaaays', 'live'),
#  ('daaaays', 'voice'),
#  ('daaaays', 'different'),
#  ('daaaays', 'too'),
#  ('daaaays', 'rican'),
#  ('daaaays', 'gotten'),
#  ('daaaays', 'colorful'),
#  ('daaaays', 'impressed'),
#  ('daaaays', 'worth'),
#  ('daaaays', 'magical'),
#  ('daaaays', 'chronological'),
#  ('daaaays', 'entire'),
#  ('daaaays', 'great'),
#  ('daaaays', 'energetic'),
#  ('daaaays', 'mobile'),
#  ('daaaays', 'much'),
#  ('daaaays', 'sexy'),
#  ('performance', 'moves'),
#  ('performance', 'couple'),
#  ('performance', 'beautiful'),
#  ('performance', 'live'),
#  ('performance', 'voice'),
#  ('performance', 'different'),
#  ('performance', 'too'),
#  ('performance', 'rican'),
#  ('performance', 'gotten'),
#  ('performance', 'colorful'),
#  ('performance', 'impressed'),
#  ('performance', 'worth'),
#  ('performance', 'magical'),
#  ('performance', 'chronological'),
#  ('performance', 'entire'),
#  ('performance', 'great'),
#  ('performance', 'energetic'),
#  ('performance', 'mobile'),
#  ('performance', 'much'),
#  ('performance', 'sexy'),
#  ('set', 'moves'),
#  ('set', 'couple'),
#  ('set', 'beautiful'),
#  ('set', 'live'),
#  ('set', 'voice'),
#  ('set', 'different'),
#  ('set', 'too'),
#  ('set', 'rican'),
#  ('set', 'gotten'),
#  ('set', 'colorful'),
#  ('set', 'impressed'),
#  ('set', 'worth'),
#  ('set', 'magical'),
#  ('set', 'chronological'),
#  ('set', 'entire'),
#  ('set', 'great'),
#  ('set', 'energetic'),
#  ('set', 'mobile'),
#  ('set', 'much'),
#  ('set', 'sexy'),
#  ('shape', 'moves'),
#  ('shape', 'couple'),
#  ('shape', 'beautiful'),
#  ('shape', 'live'),
#  ('shape', 'voice'),
#  ('shape', 'different'),
#  ('shape', 'too'),
#  ('shape', 'rican'),
#  ('shape', 'gotten'),
#  ('shape', 'colorful'),
#  ('shape', 'impressed'),
#  ('shape', 'worth'),
#  ('shape', 'magical'),
#  ('shape', 'chronological'),
#  ('shape', 'entire'),
#  ('shape', 'great'),
#  ('shape', 'energetic'),
#  ('shape', 'mobile'),
#  ('shape', 'much'),
#  ('shape', 'sexy'),
#  ('production', 'moves'),
#  ('production', 'couple'),
#  ('production', 'beautiful'),
#  ('production', 'live'),
#  ('production', 'voice'),
#  ('production', 'different'),
#  ('production', 'too'),
#  ('production', 'rican'),
#  ('production', 'gotten'),
#  ('production', 'colorful'),
#  ('production', 'impressed'),
#  ('production', 'worth'),
#  ('production', 'magical'),
#  ('production', 'chronological'),
#  ('production', 'entire'),
#  ('production', 'great'),
#  ('production', 'energetic'),
#  ('production', 'mobile'),
#  ('production', 'much'),
#  ('production', 'sexy'),
#  ('stage', 'moves'),
#  ('stage', 'couple'),
#  ('stage', 'beautiful'),
#  ('stage', 'live'),
#  ('stage', 'voice'),
#  ('stage', 'different'),
#  ('stage', 'too'),
#  ('stage', 'rican'),
#  ('stage', 'gotten'),
#  ('stage', 'colorful'),
#  ('stage', 'impressed'),
#  ('stage', 'worth'),
#  ('stage', 'magical'),
#  ('stage', 'chronological'),
#  ('stage', 'entire'),
#  ('stage', 'great'),
#  ('stage', 'energetic'),
#  ('stage', 'mobile'),
#  ('stage', 'much'),
#  ('stage', 'sexy'),
#  ('swag', 'moves'),
#  ('swag', 'couple'),
#  ('swag', 'beautiful'),
#  ('swag', 'live'),
#  ('swag', 'voice'),
#  ('swag', 'different'),
#  ('swag', 'too'),
#  ('swag', 'rican'),
#  ('swag', 'gotten'),
#  ('swag', 'colorful'),
#  ('swag', 'impressed'),
#  ('swag', 'worth'),
#  ('swag', 'magical'),
#  ('swag', 'chronological'),
#  ('swag', 'entire'),
#  ('swag', 'great'),
#  ('swag', 'energetic'),
#  ('swag', 'mobile'),
#  ('swag', 'much'),
#  ('swag', 'sexy'),
#  ('look', 'moves'),
#  ('look', 'couple'),
#  ('look', 'beautiful'),
#  ('look', 'live'),
#  ('look', 'voice'),
#  ('look', 'different'),
#  ('look', 'too'),
#  ('look', 'rican'),
#  ('look', 'gotten'),
#  ('look', 'colorful'),
#  ('look', 'impressed'),
#  ('look', 'worth'),
#  ('look', 'magical'),
#  ('look', 'chronological'),
#  ('look', 'entire'),
#  ('look', 'great'),
#  ('look', 'energetic'),
#  ('look', 'mobile'),
#  ('look', 'much'),
#  ('look', 'sexy'),
#  ('lol', 'moves'),
#  ('lol', 'couple'),
#  ('lol', 'beautiful'),
#  ('lol', 'live'),
#  ('lol', 'voice'),
#  ('lol', 'different'),
#  ('lol', 'too'),
#  ('lol', 'rican'),
#  ('lol', 'gotten'),
#  ('lol', 'colorful'),
#  ('lol', 'impressed'),
#  ('lol', 'worth'),
#  ('lol', 'magical'),
#  ('lol', 'chronological'),
#  ('lol', 'entire'),
#  ('lol', 'great'),
#  ('lol', 'energetic'),
#  ('lol', 'mobile'),
#  ('lol', 'much'),
#  ('lol', 'sexy'),
#  ('beautiful', 'moves'),
#  ('beautiful', 'couple'),
#  ('beautiful', 'beautiful'),
#  ('beautiful', 'live'),
#  ('beautiful', 'voice'),
#  ('beautiful', 'different'),
#  ('beautiful', 'too'),
#  ('beautiful', 'rican'),
#  ('beautiful', 'gotten'),
#  ('beautiful', 'colorful'),
#  ('beautiful', 'impressed'),
#  ('beautiful', 'worth'),
#  ('beautiful', 'magical'),
#  ('beautiful', 'chronological'),
#  ('beautiful', 'entire'),
#  ('beautiful', 'great'),
#  ('beautiful', 'energetic'),
#  ('beautiful', 'mobile'),
#  ('beautiful', 'much'),
#  ('beautiful', 'sexy'),
#  ('head', 'moves'),
#  ('head', 'couple'),
#  ('head', 'beautiful'),
#  ('head', 'live'),
#  ('head', 'voice'),
#  ('head', 'different'),
#  ('head', 'too'),
#  ('head', 'rican'),
#  ('head', 'gotten'),
#  ('head', 'colorful'),
#  ('head', 'impressed'),
#  ('head', 'worth'),
#  ('head', 'magical'),
#  ('head', 'chronological'),
#  ('head', 'entire'),
#  ('head', 'great'),
#  ('head', 'energetic'),
#  ('head', 'mobile'),
#  ('head', 'much'),
#  ('head', 'sexy'),
#  ('penny', 'moves'),
#  ('penny', 'couple'),
#  ('penny', 'beautiful'),
#  ('penny', 'live'),
#  ('penny', 'voice'),
#  ('penny', 'different'),
#  ('penny', 'too'),
#  ('penny', 'rican'),
#  ('penny', 'gotten'),
#  ('penny', 'colorful'),
#  ('penny', 'impressed'),
#  ('penny', 'worth'),
#  ('penny', 'magical'),
#  ('penny', 'chronological'),
#  ('penny', 'entire'),
#  ('penny', 'great'),
#  ('penny', 'energetic'),
#  ('penny', 'mobile'),
#  ('penny', 'much'),
#  ('penny', 'sexy'),
#  ('brooklyn', 'moves'),
#  ('brooklyn', 'couple'),
#  ('brooklyn', 'beautiful'),
#  ('brooklyn', 'live'),
#  ('brooklyn', 'voice'),
#  ('brooklyn', 'different'),
#  ('brooklyn', 'too'),
#  ('brooklyn', 'rican'),
#  ('brooklyn', 'gotten'),
#  ('brooklyn', 'colorful'),
#  ('brooklyn', 'impressed'),
#  ('brooklyn', 'worth'),
#  ('brooklyn', 'magical'),
#  ('brooklyn', 'chronological'),
#  ('brooklyn', 'entire'),
#  ('brooklyn', 'great'),
#  ('brooklyn', 'energetic'),
#  ('brooklyn', 'mobile'),
#  ('brooklyn', 'much'),
#  ('brooklyn', 'sexy'),
#  ('coconuts', 'moves'),
#  ('coconuts', 'couple'),
#  ('coconuts', 'beautiful'),
#  ('coconuts', 'live'),
#  ('coconuts', 'voice'),
#  ('coconuts', 'different'),
#  ('coconuts', 'too'),
#  ('coconuts', 'rican'),
#  ('coconuts', 'gotten'),
#  ('coconuts', 'colorful'),
#  ('coconuts', 'impressed'),
#  ('coconuts', 'worth'),
#  ('coconuts', 'magical'),
#  ('coconuts', 'chronological'),
#  ('coconuts', 'entire'),
#  ('coconuts', 'great'),
#  ('coconuts', 'energetic'),
#  ('coconuts', 'mobile'),
#  ('coconuts', 'much'),
#  ('coconuts', 'sexy'),
#  ('photography', 'moves'),
#  ('photography', 'couple'),
#  ('photography', 'beautiful'),
#  ('photography', 'live'),
#  ('photography', 'voice'),
#  ('photography', 'different'),
#  ('photography', 'too'),
#  ('photography', 'rican'),
#  ('photography', 'gotten'),
#  ('photography', 'colorful'),
#  ('photography', 'impressed'),
#  ('photography', 'worth'),
#  ('photography', 'magical'),
#  ('photography', 'chronological'),
#  ('photography', 'entire'),
#  ('photography', 'great'),
#  ('photography', 'energetic'),
#  ('photography', 'mobile'),
#  ('photography', 'much'),
#  ('photography', 'sexy'),
#  ('song', 'moves'),
#  ('song', 'couple'),
#  ('song', 'beautiful'),
#  ('song', 'live'),
#  ('song', 'voice'),
#  ('song', 'different'),
#  ('song', 'too'),
#  ('song', 'rican'),
#  ('song', 'gotten'),
#  ('song', 'colorful'),
#  ('song', 'impressed'),
#  ('song', 'worth'),
#  ('song', 'magical'),
#  ('song', 'chronological'),
#  ('song', 'entire'),
#  ('song', 'great'),
#  ('song', 'energetic'),
#  ('song', 'mobile'),
#  ('song', 'much'),
#  ('song', 'sexy'),
#  ('energy', 'moves'),
#  ('energy', 'couple'),
#  ('energy', 'beautiful'),
#  ('energy', 'live'),
#  ('energy', 'voice'),
#  ('energy', 'different'),
#  ('energy', 'too'),
#  ('energy', 'rican'),
#  ('energy', 'gotten'),
#  ('energy', 'colorful'),
#  ('energy', 'impressed'),
#  ('energy', 'worth'),
#  ('energy', 'magical'),
#  ('energy', 'chronological'),
#  ('energy', 'entire'),
#  ('energy', 'great'),
#  ('energy', 'energetic'),
#  ('energy', 'mobile'),
#  ('energy', 'much'),
#  ('energy', 'sexy'),
#  ('voice', 'moves'),
#  ('voice', 'couple'),
#  ('voice', 'beautiful'),
#  ('voice', 'live'),
#  ('voice', 'voice'),
#  ('voice', 'different'),
#  ('voice', 'too'),
#  ('voice', 'rican'),
#  ('voice', 'gotten'),
#  ('voice', 'colorful'),
#  ('voice', 'impressed'),
#  ('voice', 'worth'),
#  ('voice', 'magical'),
#  ('voice', 'chronological'),
#  ('voice', 'entire'),
#  ('voice', 'great'),
#  ('voice', 'energetic'),
#  ('voice', 'mobile'),
#  ('voice', 'much'),
#  ('voice', 'sexy'),
#  ('everything', 'moves'),
#  ('everything', 'couple'),
#  ('everything', 'beautiful'),
#  ('everything', 'live'),
#  ('everything', 'voice'),
#  ('everything', 'different'),
#  ('everything', 'too'),
#  ('everything', 'rican'),
#  ('everything', 'gotten'),
#  ('everything', 'colorful'),
#  ('everything', 'impressed'),
#  ('everything', 'worth'),
#  ('everything', 'magical'),
#  ('everything', 'chronological'),
#  ('everything', 'entire'),
#  ('everything', 'great'),
#  ('everything', 'energetic'),
#  ('everything', 'mobile'),
#  ('everything', 'much'),
#  ('everything', 'sexy'),
#  ('anything', 'moves'),
#  ('anything', 'couple'),
#  ('anything', 'beautiful'),
#  ('anything', 'live'),
#  ('anything', 'voice'),
#  ('anything', 'different'),
#  ('anything', 'too'),
#  ('anything', 'rican'),
#  ('anything', 'gotten'),
#  ('anything', 'colorful'),
#  ('anything', 'impressed'),
#  ('anything', 'worth'),
#  ('anything', 'magical'),
#  ('anything', 'chronological'),
#  ('anything', 'entire'),
#  ('anything', 'great'),
#  ('anything', 'energetic'),
#  ('anything', 'mobile'),
#  ('anything', 'much'),
#  ('anything', 'sexy'),
#  ('hits', 'moves'),
#  ('hits', 'couple'),
#  ('hits', 'beautiful'),
#  ('hits', 'live'),
#  ('hits', 'voice'),
#  ('hits', 'different'),
#  ('hits', 'too'),
#  ('hits', 'rican'),
#  ('hits', 'gotten'),
#  ('hits', 'colorful'),
#  ('hits', 'impressed'),
#  ('hits', 'worth'),
#  ('hits', 'magical'),
#  ('hits', 'chronological'),
#  ('hits', 'entire'),
#  ('hits', 'great'),
#  ('hits', 'energetic'),
#  ('hits', 'mobile'),
#  ('hits', 'much'),
#  ('hits', 'sexy'),
#  ('the', 'moves'),
#  ('the', 'couple'),
#  ('the', 'beautiful'),
#  ('the', 'live'),
#  ('the', 'voice'),
#  ('the', 'different'),
#  ('the', 'too'),
#  ('the', 'rican'),
#  ('the', 'gotten'),
#  ('the', 'colorful'),
#  ('the', 'impressed'),
#  ('the', 'worth'),
#  ('the', 'magical'),
#  ('the', 'chronological'),
#  ('the', 'entire'),
#  ('the', 'great'),
#  ('the', 'energetic'),
#  ('the', 'mobile'),
#  ('the', 'much'),
#  ('the', 'sexy'),
#  ('grammys', 'moves'),
#  ('grammys', 'couple'),
#  ('grammys', 'beautiful'),
#  ('grammys', 'live'),
#  ('grammys', 'voice'),
#  ('grammys', 'different'),
#  ('grammys', 'too'),
#  ('grammys', 'rican'),
#  ('grammys', 'gotten'),
#  ('grammys', 'colorful'),
#  ('grammys', 'impressed'),
#  ('grammys', 'worth'),
#  ('grammys', 'magical'),
#  ('grammys', 'chronological'),
#  ('grammys', 'entire'),
#  ('grammys', 'great'),
#  ('grammys', 'energetic'),
#  ('grammys', 'mobile'),
#  ('grammys', 'much'),
#  ('grammys', 'sexy'),
#  ('donatella', 'moves'),
#  ('donatella', 'couple'),
#  ('donatella', 'beautiful'),
#  ('donatella', 'live'),
#  ('donatella', 'voice'),
#  ('donatella', 'different'),
#  ('donatella', 'too'),
#  ('donatella', 'rican'),
#  ('donatella', 'gotten'),
#  ('donatella', 'colorful'),
#  ('donatella', 'impressed'),
#  ('donatella', 'worth'),
#  ('donatella', 'magical'),
#  ('donatella', 'chronological'),
#  ('donatella', 'entire'),
#  ('donatella', 'great'),
#  ('donatella', 'energetic'),
#  ('donatella', 'mobile'),
#  ('donatella', 'much'),
#  ('donatella', 'sexy'),
#  ('fun', 'moves'),
#  ('fun', 'couple'),
#  ('fun', 'beautiful'),
#  ('fun', 'live'),
#  ('fun', 'voice'),
#  ('fun', 'different'),
#  ('fun', 'too'),
#  ('fun', 'rican'),
#  ('fun', 'gotten'),
#  ('fun', 'colorful'),
#  ('fun', 'impressed'),
#  ('fun', 'worth'),
#  ('fun', 'magical'),
#  ('fun', 'chronological'),
#  ('fun', 'entire'),
#  ('fun', 'great'),
#  ('fun', 'energetic'),
#  ('fun', 'mobile'),
#  ('fun', 'much'),
#  ('fun', 'sexy'),
#  ('costumes', 'moves'),
#  ('costumes', 'couple'),
#  ('costumes', 'beautiful'),
#  ('costumes', 'live'),
#  ('costumes', 'voice'),
#  ('costumes', 'different'),
#  ('costumes', 'too'),
#  ('costumes', 'rican'),
#  ('costumes', 'gotten'),
#  ('costumes', 'colorful'),
#  ('costumes', 'impressed'),
#  ('costumes', 'worth'),
#  ('costumes', 'magical'),
#  ('costumes', 'chronological'),
#  ('costumes', 'entire'),
#  ('costumes', 'great'),
#  ('costumes', 'energetic'),
#  ('costumes', 'mobile'),
#  ('costumes', 'much'),
#  ('costumes', 'sexy'),
#  ('order', 'moves'),
#  ('order', 'couple'),
#  ('order', 'beautiful'),
#  ('order', 'live'),
#  ('order', 'voice'),
#  ('order', 'different'),
#  ('order', 'too'),
#  ('order', 'rican'),
#  ('order', 'gotten'),
#  ('order', 'colorful'),
#  ('order', 'impressed'),
#  ('order', 'worth'),
#  ('order', 'magical'),
#  ('order', 'chronological'),
#  ('order', 'entire'),
#  ('order', 'great'),
#  ('order', 'energetic'),
#  ('order', 'mobile'),
#  ('order', 'much'),
#  ('order', 'sexy'),
#  ('hotter', 'moves'),
#  ('hotter', 'couple'),
#  ('hotter', 'beautiful'),
#  ('hotter', 'live'),
#  ('hotter', 'voice'),
#  ('hotter', 'different'),
#  ('hotter', 'too'),
#  ('hotter', 'rican'),
#  ('hotter', 'gotten'),
#  ('hotter', 'colorful'),
#  ('hotter', 'impressed'),
#  ('hotter', 'worth'),
#  ('hotter', 'magical'),
#  ('hotter', 'chronological'),
#  ('hotter', 'entire'),
#  ('hotter', 'great'),
#  ('hotter', 'energetic'),
#  ('hotter', 'mobile'),
#  ('hotter', 'much'),
#  ('hotter', 'sexy'),
#  ('diva', 'moves'),
#  ('diva', 'couple'),
#  ('diva', 'beautiful'),
#  ('diva', 'live'),
#  ('diva', 'voice'),
#  ('diva', 'different'),
#  ('diva', 'too'),
#  ('diva', 'rican'),
#  ('diva', 'gotten'),
#  ('diva', 'colorful'),
#  ('diva', 'impressed'),
#  ('diva', 'worth'),
#  ('diva', 'magical'),
#  ('diva', 'chronological'),
#  ('diva', 'entire'),
#  ('diva', 'great'),
#  ('diva', 'energetic'),
#  ('diva', 'mobile'),
#  ('diva', 'much'),
#  ('diva', 'sexy'),
#  ('jlo', 'moves'),
#  ('jlo', 'couple'),
#  ('jlo', 'beautiful'),
#  ('jlo', 'live'),
#  ('jlo', 'voice'),
#  ('jlo', 'different'),
#  ('jlo', 'too'),
#  ('jlo', 'rican'),
#  ('jlo', 'gotten'),
#  ('jlo', 'colorful'),
#  ('jlo', 'impressed'),
#  ('jlo', 'worth'),
#  ('jlo', 'magical'),
#  ('jlo', 'chronological'),
#  ('jlo', 'entire'),
#  ('jlo', 'great'),
#  ('jlo', 'energetic'),
#  ('jlo', 'mobile'),
#  ('jlo', 'much'),
#  ('jlo', 'sexy'),
#  ('styles', 'moves'),
#  ('styles', 'couple'),
#  ('styles', 'beautiful'),
#  ('styles', 'live'),
#  ('styles', 'voice'),
#  ('styles', 'different'),
#  ('styles', 'too'),
#  ('styles', 'rican'),
#  ('styles', 'gotten'),
#  ('styles', 'colorful'),
#  ('styles', 'impressed'),
#  ('styles', 'worth'),
#  ('styles', 'magical'),
#  ('styles', 'chronological'),
#  ('styles', 'entire'),
#  ('styles', 'great'),
#  ('styles', 'energetic'),
#  ('styles', 'mobile'),
#  ('styles', 'much'),
#  ('styles', 'sexy'),
#  ('concert', 'moves'),
#  ('concert', 'couple'),
#  ('concert', 'beautiful'),
#  ('concert', 'live'),
#  ('concert', 'voice'),
#  ('concert', 'different'),
#  ('concert', 'too'),
#  ('concert', 'rican'),
#  ('concert', 'gotten'),
#  ('concert', 'colorful'),
#  ('concert', 'impressed'),
#  ('concert', 'worth'),
#  ('concert', 'magical'),
#  ('concert', 'chronological'),
#  ('concert', 'entire'),
#  ('concert', 'great'),
#  ('concert', 'energetic'),
#  ('concert', 'mobile'),
#  ('concert', 'much'),
#  ('concert', 'sexy'),
#  ('sound', 'moves'),
#  ('sound', 'couple'),
#  ('sound', 'beautiful'),
#  ('sound', 'live'),
#  ('sound', 'voice'),
#  ('sound', 'different'),
#  ('sound', 'too'),
#  ('sound', 'rican'),
#  ('sound', 'gotten'),
#  ('sound', 'colorful'),
#  ('sound', 'impressed'),
#  ('sound', 'worth'),
#  ('sound', 'magical'),
#  ('sound', 'chronological'),
#  ('sound', 'entire'),
#  ('sound', 'great'),
#  ('sound', 'energetic'),
#  ('sound', 'mobile'),
#  ('sound', 'much'),
#  ('sound', 'sexy'),
#  ('mother', 'moves'),
#  ('mother', 'couple'),
#  ('mother', 'beautiful'),
#  ('mother', 'live'),
#  ('mother', 'voice'),
#  ('mother', 'different'),
#  ('mother', 'too'),
#  ('mother', 'rican'),
#  ('mother', 'gotten'),
#  ('mother', 'colorful'),
#  ('mother', 'impressed'),
#  ('mother', 'worth'),
#  ('mother', 'magical'),
#  ('mother', 'chronological'),
#  ('mother', 'entire'),
#  ('mother', 'great'),
#  ('mother', 'energetic'),
#  ('mother', 'mobile'),
#  ('mother', 'much'),
#  ('mother', 'sexy'),
#  ('dress', 'moves'),
#  ('dress', 'couple'),
#  ('dress', 'beautiful'),
#  ('dress', 'live'),
#  ('dress', 'voice'),
#  ('dress', 'different'),
#  ('dress', 'too'),
#  ('dress', 'rican'),
#  ('dress', 'gotten'),
#  ('dress', 'colorful'),
#  ('dress', 'impressed'),
#  ('dress', 'worth'),
#  ('dress', 'magical'),
#  ('dress', 'chronological'),
#  ('dress', 'entire'),
#  ('dress', 'great'),
#  ('dress', 'energetic'),
#  ('dress', 'mobile'),
#  ('dress', 'much'),
#  ('dress', 'sexy'),
#  ('woman', 'moves'),
#  ('woman', 'couple'),
#  ('woman', 'beautiful'),
#  ('woman', 'live'),
#  ('woman', 'voice'),
#  ('woman', 'different'),
#  ('woman', 'too'),
#  ('woman', 'rican'),
#  ('woman', 'gotten'),
#  ('woman', 'colorful'),
#  ('woman', 'impressed'),
#  ('woman', 'worth'),
#  ('woman', 'magical'),
#  ('woman', 'chronological'),
#  ('woman', 'entire'),
#  ('woman', 'great'),
#  ('woman', 'energetic'),
#  ('woman', 'mobile'),
#  ('woman', 'much'),
#  ('woman', 'sexy'),
#  ('bucks', 'moves'),
#  ('bucks', 'couple'),
#  ('bucks', 'beautiful'),
#  ('bucks', 'live'),
#  ('bucks', 'voice'),
#  ('bucks', 'different'),
#  ('bucks', 'too'),
#  ('bucks', 'rican'),
#  ('bucks', 'gotten'),
#  ('bucks', 'colorful'),
#  ('bucks', 'impressed'),
#  ('bucks', 'worth'),
#  ('bucks', 'magical'),
#  ('bucks', 'chronological'),
#  ('bucks', 'entire'),
#  ('bucks', 'great'),
#  ('bucks', 'energetic'),
#  ('bucks', 'mobile'),
#  ('bucks', 'much'),
#  ('bucks', 'sexy'),
#  ('wonder', 'moves'),
#  ('wonder', 'couple'),
#  ('wonder', 'beautiful'),
#  ('wonder', 'live'),
#  ('wonder', 'voice'),
#  ('wonder', 'different'),
#  ('wonder', 'too'),
#  ('wonder', 'rican'),
#  ('wonder', 'gotten'),
#  ('wonder', 'colorful'),
#  ('wonder', 'impressed'),
#  ('wonder', 'worth'),
#  ('wonder', 'magical'),
#  ('wonder', 'chronological'),
#  ('wonder', 'entire'),
#  ('wonder', 'great'),
#  ('wonder', 'energetic'),
#  ('wonder', 'mobile'),
#  ('wonder', 'much'),
#  ('wonder', 'sexy'),
#  ('hall', 'moves'),
#  ('hall', 'couple'),
#  ('hall', 'beautiful'),
#  ('hall', 'live'),
#  ('hall', 'voice'),
#  ('hall', 'different'),
#  ('hall', 'too'),
#  ('hall', 'rican'),
#  ('hall', 'gotten'),
#  ('hall', 'colorful'),
#  ('hall', 'impressed'),
#  ('hall', 'worth'),
#  ('hall', 'magical'),
#  ('hall', 'chronological'),
#  ('hall', 'entire'),
#  ('hall', 'great'),
#  ('hall', 'energetic'),
#  ('hall', 'mobile'),
#  ('hall', 'much'),
#  ('hall', 'sexy'),
#  ('green', 'moves'),
#  ('green', 'couple'),
#  ('green', 'beautiful'),
#  ('green', 'live'),
#  ('green', 'voice'),
#  ('green', 'different'),
#  ('green', 'too'),
#  ('green', 'rican'),
#  ('green', 'gotten'),
#  ('green', 'colorful'),
#  ('green', 'impressed'),
#  ('green', 'worth'),
#  ('green', 'magical'),
#  ('green', 'chronological'),
#  ('green', 'entire'),
#  ('green', 'great'),
#  ('green', 'energetic'),
#  ('green', 'mobile'),
#  ('green', 'much'),
#  ('green', 'sexy'),
#  ('vegas', 'moves'),
#  ('vegas', 'couple'),
#  ('vegas', 'beautiful'),
#  ('vegas', 'live'),
#  ('vegas', 'voice'),
#  ('vegas', 'different'),
#  ('vegas', 'too'),
#  ('vegas', 'rican'),
#  ('vegas', 'gotten'),
#  ('vegas', 'colorful'),
#  ('vegas', 'impressed'),
#  ('vegas', 'worth'),
#  ('vegas', 'magical'),
#  ('vegas', 'chronological'),
#  ('vegas', 'entire'),
#  ('vegas', 'great'),
#  ('vegas', 'energetic'),
#  ('vegas', 'mobile'),
#  ('vegas', 'much'),
#  ('vegas', 'sexy'),
#  ('seats', 'moves'),
#  ('seats', 'couple'),
#  ('seats', 'beautiful'),
#  ('seats', 'live'),
#  ('seats', 'voice'),
#  ('seats', 'different'),
#  ('seats', 'too'),
#  ('seats', 'rican'),
#  ('seats', 'gotten'),
#  ('seats', 'colorful'),
#  ('seats', 'impressed'),
#  ('seats', 'worth'),
#  ('seats', 'magical'),
#  ('seats', 'chronological'),
#  ('seats', 'entire'),
#  ('seats', 'great'),
#  ('seats', 'energetic'),
#  ('seats', 'mobile'),
#  ('seats', 'much'),
#  ('seats', 'sexy'),
#  ('jlo', 'moves'),
#  ('jlo', 'couple'),
#  ('jlo', 'beautiful'),
#  ('jlo', 'live'),
#  ('jlo', 'voice'),
#  ('jlo', 'different'),
#  ('jlo', 'too'),
#  ('jlo', 'rican'),
#  ('jlo', 'gotten'),
#  ('jlo', 'colorful'),
#  ('jlo', 'impressed'),
#  ('jlo', 'worth'),
#  ('jlo', 'magical'),
#  ('jlo', 'chronological'),
#  ('jlo', 'entire'),
#  ('jlo', 'great'),
#  ('jlo', 'energetic'),
#  ('jlo', 'mobile'),
#  ('jlo', 'much'),
#  ('jlo', 'sexy'),
#  ('street', 'moves'),
#  ('street', 'couple'),
#  ('street', 'beautiful'),
#  ('street', 'live'),
#  ('street', 'voice'),
#  ('street', 'different'),
#  ('street', 'too'),
#  ('street', 'rican'),
#  ('street', 'gotten'),
#  ('street', 'colorful'),
#  ('street', 'impressed'),
#  ('street', 'worth'),
#  ('street', 'magical'),
#  ('street', 'chronological'),
#  ('street', 'entire'),
#  ('street', 'great'),
#  ('street', 'energetic'),
#  ('street', 'mobile'),
#  ('street', 'much'),
#  ('street', 'sexy'),
#  ('lighting', 'moves'),
#  ('lighting', 'couple'),
#  ('lighting', 'beautiful'),
#  ('lighting', 'live'),
#  ('lighting', 'voice'),
#  ('lighting', 'different'),
#  ('lighting', 'too'),
#  ('lighting', 'rican'),
#  ('lighting', 'gotten'),
#  ('lighting', 'colorful'),
#  ('lighting', 'impressed'),
#  ('lighting', 'worth'),
#  ('lighting', 'magical'),
#  ('lighting', 'chronological'),
#  ('lighting', 'entire'),
#  ('lighting', 'great'),
#  ('lighting', 'energetic'),
#  ('lighting', 'mobile'),
#  ('lighting', 'much'),
#  ('lighting', 'sexy'),
#  ('flawless', 'moves'),
#  ('flawless', 'couple'),
#  ('flawless', 'beautiful'),
#  ('flawless', 'live'),
#  ('flawless', 'voice'),
#  ('flawless', 'different'),
#  ('flawless', 'too'),
#  ('flawless', 'rican'),
#  ('flawless', 'gotten'),
#  ('flawless', 'colorful'),
#  ('flawless', 'impressed'),
#  ('flawless', 'worth'),
#  ('flawless', 'magical'),
#  ('flawless', 'chronological'),
#  ('flawless', 'entire'),
#  ('flawless', 'great'),
#  ('flawless', 'energetic'),
#  ('flawless', 'mobile'),
#  ('flawless', 'much'),
#  ('flawless', 'sexy'),
#  ('time', 'moves'),
#  ('time', 'couple'),
#  ('time', 'beautiful'),
#  ('time', 'live'),
#  ('time', 'voice'),
#  ('time', 'different'),
#  ('time', 'too'),
#  ('time', 'rican'),
#  ('time', 'gotten'),
#  ('time', 'colorful'),
#  ('time', 'impressed'),
#  ('time', 'worth'),
#  ('time', 'magical'),
#  ('time', 'chronological'),
#  ('time', 'entire'),
#  ('time', 'great'),
#  ('time', 'energetic'),
#  ('time', 'mobile'),
#  ('time', 'much'),
#  ('time', 'sexy'),
#  ('outfits', 'moves'),
#  ('outfits', 'couple'),
#  ('outfits', 'beautiful'),
#  ('outfits', 'live'),
#  ('outfits', 'voice'),
#  ('outfits', 'different'),
#  ('outfits', 'too'),
#  ('outfits', 'rican'),
#  ('outfits', 'gotten'),
#  ('outfits', 'colorful'),
#  ('outfits', 'impressed'),
#  ('outfits', 'worth'),
#  ('outfits', 'magical'),
#  ('outfits', 'chronological'),
#  ('outfits', 'entire'),
#  ('outfits', 'great'),
#  ('outfits', 'energetic'),
#  ('outfits', 'mobile'),
#  ('outfits', 'much'),
#  ('outfits', 'sexy'),
#  ('minute', 'moves'),
#  ('minute', 'couple'),
#  ('minute', 'beautiful'),
#  ('minute', 'live'),
#  ('minute', 'voice'),
#  ('minute', 'different'),
#  ('minute', 'too'),
#  ('minute', 'rican'),
#  ('minute', 'gotten'),
#  ('minute', 'colorful'),
#  ('minute', 'impressed'),
#  ('minute', 'worth'),
#  ('minute', 'magical'),
#  ('minute', 'chronological'),
#  ('minute', 'entire'),
#  ('minute', 'great'),
#  ('minute', 'energetic'),
#  ('minute', 'mobile'),
#  ('minute', 'much'),
#  ('minute', 'sexy'),
#  ...]

# %%
seen = set()
repeated = {}

for pair in pairs_list:
    if pair in seen:
        if pair in repeated:
            repeated[pair] += 1
        else:
            repeated[pair] = 2
    else:
        seen.add(pair)

# %%
repeated = {k:v for k,v in sorted(repeated.items(), key=lambda x:x[1], reverse=True)}

repeated
# Out:
# {('show', 'great'): 10,
#  ('jlo', 'great'): 9,
#  ('jlo', 'good'): 9,
#  ('seats', 'good'): 7,
#  ('seats', 'great'): 7,
#  ('show', 'good'): 6,
#  ('jlo', 'huge'): 6,
#  ('show', 'amazing'): 6,
#  ('fan', 'huge'): 6,
#  ('time', 'great'): 6,
#  ('jlo', 'beautiful'): 5,
#  ('jlo', 'much'): 5,
#  ('jlo', 'able'): 5,
#  ('jlo', 'more'): 5,
#  ('concert', 'good'): 5,
#  ('show', 'high'): 5,
#  ('show', 'huge'): 5,
#  ('jlo', 'old'): 5,
#  ('jlo', 'cool'): 5,
#  ('time', 'huge'): 5,
#  ('stage', 'great'): 5,
#  ('vegas', 'great'): 5,
#  ('jlo', 'many'): 5,
#  ('jlo', 'sexy'): 4,
#  ('jlo', 'last'): 4,
#  ('seats', 'able'): 4,
#  ('concert', 'first'): 4,
#  ('concert', 'able'): 4,
#  ('show', 'old'): 4,
#  ('time', 'beautiful'): 4,
#  ('jlo', 'amazing'): 4,
#  ('people', 'able'): 4,
#  ('people', 'good'): 4,
#  ('time', 'able'): 4,
#  ('time', 'good'): 4,
#  ('jlo', 'hard'): 4,
#  ('show', 'best'): 4,
#  ('vegas', 'good'): 4,
#  ('show', 'first'): 4,
#  ('concert', 'bad'): 4,
#  ('show', 'bad'): 4,
#  ('people', 'bad'): 4,
#  ('music', 'more'): 4,
#  ('lo', 'amazing'): 4,
#  ('seats', 'much'): 4,
#  ('changes', 'good'): 4,
#  ('experience', 'good'): 4,
#  ('jlo', 'talented'): 4,
#  ('dance', 'great'): 4,
#  ('show', 'better'): 4,
#  ('', 'great'): 4,
#  ('people', 'great'): 4,
#  ('songs', 'great'): 4,
#  ('songs', 'many'): 4,
#  ('vegas', 'many'): 4,
#  ('music', 'great'): 4,
#  ('changes', 'great'): 4,
#  ('lot', 'great'): 4,
#  ('jlo', 'live'): 3,
#  ('jlo', 'worth'): 3,
#  ('choreography', 'good'): 3,
#  ('jlo', 'first'): 3,
#  ('jlo', 'nice'): 3,
#  ('jlo', 'final'): 3,
#  ('seats', 'more'): 3,
#  ('concert', 'huge'): 3,
#  ('energy', 'high'): 3,
#  ('hits', 'great'): 3,
#  ('dancers', 'high'): 3,
#  ('song', 'sexy'): 3,
#  ('hits', 'beautiful'): 3,
#  ('hours', 'old'): 3,
#  ('night', 'huge'): 3,
#  ('jlo', 'real'): 3,
#  ('jlo', 'true'): 3,
#  ('performer', 'huge'): 3,
#  ('show', 'last'): 3,
#  ('tickets', 'amazing'): 3,
#  ('fan', 'last'): 3,
#  ('seats', 'hard'): 3,
#  ('people', 'hard'): 3,
#  ('stage', 'good'): 3,
#  ('lol', 'great'): 3,
#  ('wow', 'great'): 3,
#  ('rows', 'good'): 3,
#  ('lo', 'first'): 3,
#  ('concert', 'small'): 3,
#  ('dance', 'first'): 3,
#  ('everyone', 'able'): 3,
#  ('show', 'able'): 3,
#  ('stage', 'beautiful'): 3,
#  ('fun', 'great'): 3,
#  ('stars', 'more'): 3,
#  ('woman', 'more'): 3,
#  ('woman', 'great'): 3,
#  ('fan', 'more'): 3,
#  ('time', 'more'): 3,
#  ('j', 'amazing'): 3,
#  ('concert', 'much'): 3,
#  ('seats', 'amazing'): 3,
#  ('tickets', 'good'): 3,
#  ('lots', 'good'): 3,
#  ('dancers', 'great'): 3,
#  ('show', 'small'): 3,
#  ('seating', 'great'): 3,
#  ('show', 'talented'): 3,
#  ('vegas', 'talented'): 3,
#  ('show', 'entertaining'): 3,
#  ('fan', 'bad'): 3,
#  ('lo', 'great'): 3,
#  ('show', 'fabulous'): 3,
#  ('j', 'great'): 3,
#  ('costumes', 'great'): 3,
#  ('dancing', 'fabulous'): 3,
#  ('show', 'little'): 3,
#  ('dancing', 'great'): 3,
#  ('lot', 'little'): 3,
#  ('vegas', 'first'): 3,
#  ('vegas', 'best'): 3,
#  ('system', 'great'): 3,
#  ('voice', 'great'): 3,
#  ('sound', 'great'): 3,
#  ('lighting', 'great'): 3,
#  ('way', 'great'): 3,
#  ('way', 'much'): 3,
#  ('fan', 'great'): 3,
#  ('jlo', 'high'): 3,
#  ('planet', 'good'): 3,
#  ('venue', 'good'): 3,
#  ('fan', 'many'): 3,
#  ('fan', 'good'): 3,
#  ('vegas', 'amazing'): 3,
#  ('people', 'better'): 3,
#  ('jlo', 'repetitive'): 3,
#  ('jlo', 'bad'): 3,
#  ('jlo', 'full'): 3,
#  ('jlo', 'better'): 3,
#  ('show', 'most'): 3,
#  ('show', 'cool'): 3,
#  ('show', 'many'): 3,
#  ('show', 'more'): 3,
#  ('front', 'better'): 3,
#  ('front', 'great'): 3,
#  ('music', 'good'): 3,
#  ('experience', 'great'): 3,
#  ('lot', 'better'): 3,
#  ('lot', 'good'): 3,
#  ('vegas', 'more'): 3,
#  ('time', 'most'): 3,
#  ('time', 'cool'): 3,
#  ('seat', 'great'): 3,
#  ('everyone', 'great'): 3,
#  ('show', 'beautiful'): 3,
#  ('jlo', 'moves'): 2,
#  ('jlo', 'couple'): 2,
#  ('jlo', 'voice'): 2,
#  ('jlo', 'different'): 2,
#  ('jlo', 'too'): 2,
#  ('jlo', 'rican'): 2,
#  ('jlo', 'gotten'): 2,
#  ('jlo', 'colorful'): 2,
#  ('jlo', 'impressed'): 2,
#  ('jlo', 'magical'): 2,
#  ('jlo', 'chronological'): 2,
#  ('jlo', 'entire'): 2,
#  ('jlo', 'energetic'): 2,
#  ('jlo', 'mobile'): 2,
#  ('birthday', 'good'): 2,
#  ('jlo', 'few'): 2,
#  ('jlo', 'longer'): 2,
#  ('jlo', 'willing'): 2,
#  ('jlo', 'dedicated'): 2,
#  ('jlo', 'complete'): 2,
#  ('jlo', 'personal'): 2,
#  ('jlo', 'fantastic'): 2,
#  ('jlo', 'grateful'): 2,
#  ('jlo', 'typical'): 2,
#  ('jlo', 'further'): 2,
#  ('jlo', 'wish'): 2,
#  ('jlo', 'worse'): 2,
#  ('jlo', 'seated'): 2,
#  ('jlo', 'least'): 2,
#  ('seats', 'few'): 2,
#  ('seats', 'first'): 2,
#  ('seats', 'longer'): 2,
#  ('seats', 'nice'): 2,
#  ('seats', 'willing'): 2,
#  ('seats', 'dedicated'): 2,
#  ('seats', 'complete'): 2,
#  ('seats', 'personal'): 2,
#  ('seats', 'fantastic'): 2,
#  ('seats', 'huge'): 2,
#  ('seats', 'grateful'): 2,
#  ('seats', 'typical'): 2,
#  ('seats', 'further'): 2,
#  ('seats', 'wish'): 2,
#  ('seats', 'worse'): 2,
#  ('seats', 'last'): 2,
#  ('seats', 'final'): 2,
#  ('seats', 'seated'): 2,
#  ('seats', 'least'): 2,
#  ('crowd', 'good'): 2,
#  ('concert', 'few'): 2,
#  ('concert', 'longer'): 2,
#  ('concert', 'nice'): 2,
#  ('concert', 'willing'): 2,
#  ('concert', 'dedicated'): 2,
#  ('concert', 'complete'): 2,
#  ('concert', 'personal'): 2,
#  ('concert', 'fantastic'): 2,
#  ('concert', 'grateful'): 2,
#  ('concert', 'typical'): 2,
#  ('concert', 'further'): 2,
#  ('concert', 'wish'): 2,
#  ('concert', 'worse'): 2,
#  ('concert', 'last'): 2,
#  ('concert', 'final'): 2,
#  ('concert', 'more'): 2,
#  ('concert', 'seated'): 2,
#  ('concert', 'least'): 2,
#  ('dance', 'good'): 2,
#  ('stage', 'much'): 2,
#  ('the', 'much'): 2,
#  ('tickets', 'nice'): 2,
#  ('performer', 'nice'): 2,
#  ('dancers', 'nice'): 2,
#  ('times', 'nice'): 2,
#  ('energy', 'nice'): 2,
#  ('energy', 'much'): 2,
#  ('everything', 'much'): 2,
#  ('show', 'nice'): 2,
#  ('night', 'nice'): 2,
#  ('people', 'nice'): 2,
#  ('security', 'nice'): 2,
#  ('energy', 'amazing'): 2,
#  ('energy', 'great'): 2,
#  ('dancers', 'amazing'): 2,
#  ('etc', 'huge'): 2,
#  ('production', 'beautiful'): 2,
#  ('production', 'sexy'): 2,
#  ('start', 'old'): 2,
#  ('song', 'beautiful'): 2,
#  ('hits', 'sexy'): 2,
#  ('night', 'old'): 2,
#  ('jlo', 'earliest'): 2,
#  ('jlo', 'newest'): 2,
#  ('jlo', 'jealous'): 2,
#  ('jlo', 'latest'): 2,
#  ('jlo', 'recent'): 2,
#  ('jlo', 'hardest'): 2,
#  ('jlo', 'enjoyable'): 2,
#  ('jlo', 'single'): 2,
#  ('time', 'sexy'): 2,
#  ('start', 'huge'): 2,
#  ('start', 'amazing'): 2,
#  ('performer', 'amazing'): 2,
#  ('performer', 'last'): 2,
#  ('tickets', 'huge'): 2,
#  ('tickets', 'last'): 2,
#  ('show', 'real'): 2,
#  ('fan', 'real'): 2,
#  ('stage', 'live'): 2,
#  ('lol', 'live'): 2,
#  ('wow', 'ok'): 2,
#  ('wow', 'present'): 2,
#  ('wow', 'lip'): 2,
#  ('wow', 'upgrade'): 2,
#  ('wow', 'available'): 2,
#  ('wow', 'talented'): 2,
#  ('wow', 'live'): 2,
#  ('wow', 'good'): 2,
#  ('vegas', 'live'): 2,
#  ('seats', 'live'): 2,
#  ('it', 'first'): 2,
#  ('a', 'first'): 2,
#  ('people', 'first'): 2,
#  ('choreography', 'first'): 2,
#  ('lo', 'small'): 2,
#  ('lo', 'awesome'): 2,
#  ('lo', 'outro'): 2,
#  ('lo', 'bad'): 2,
#  ('concert', 'awesome'): 2,
#  ('concert', 'outro'): 2,
#  ('everyone', 'huge'): 2,
#  ('dancers', 'huge'): 2,
#  ('dancers', 'able'): 2,
#  ('dancers', 'other'): 2,
#  ('show', 'true'): 2,
#  ('show', 'other'): 2,
#  ('night', 'able'): 2,
#  ('night', 'true'): 2,
#  ('people', 'huge'): 2,
#  ('screens', 'able'): 2,
#  ('money', 'huge'): 2,
#  ('money', 'able'): 2,
#  ('trip', 'huge'): 2,
#  ('trip', 'able'): 2,
#  ('songs', 'huge'): 2,
#  ('songs', 'true'): 2,
#  ('fan', 'able'): 2,
#  ('fan', 'true'): 2,
#  ('vegas', 'huge'): 2,
#  ('vegas', 'able'): 2,
#  ('time', 'true'): 2,
#  ('music', 'huge'): 2,
#  ('music', 'few'): 2,
#  ('music', 'nice'): 2,
#  ('stage', 'worth'): 2,
#  ('stage', 'nice'): 2,
#  ('stage', 'big'): 2,
#  ('stage', 'entire'): 2,
#  ('dress', 'worth'): 2,
#  ('dress', 'beautiful'): 2,
#  ('dress', 'great'): 2,
#  ('dress', 'entire'): 2,
#  ('fun', 'worth'): 2,
#  ('fun', 'beautiful'): 2,
#  ('fun', 'entire'): 2,
#  ('hours', 'huge'): 2,
#  ('hours', 'beautiful'): 2,
#  ('hours', 'nice'): 2,
#  ('stars', 'huge'): 2,
#  ('stars', 'few'): 2,
#  ('stars', 'nice'): 2,
#  ('thing', 'huge'): 2,
#  ('thing', 'beautiful'): 2,
#  ('lobby', 'big'): 2,
#  ('woman', 'huge'): 2,
#  ('woman', 'few'): 2,
#  ('woman', 'worth'): 2,
#  ('woman', 'beautiful'): 2,
#  ('woman', 'nice'): 2,
#  ('woman', 'entire'): 2,
#  ('fan', 'few'): 2,
#  ('fan', 'beautiful'): 2,
#  ('fan', 'nice'): 2,
#  ('opinion', 'huge'): 2,
#  ('time', 'few'): 2,
#  ('time', 'worth'): 2,
#  ('time', 'nice'): 2,
#  ('time', 'big'): 2,
#  ('time', 'entire'): 2,
#  ('side', 'amazing'): 2,
#  ('tickets', 'much'): 2,
#  ('show', 'much'): 2,
#  ('lo', 'motherly'): 2,
#  ('lo', 'much'): 2,
#  ('lo', 'expensive'): 2,
#  ('dancers', 'good'): 2,
#  ('costume', 'good'): 2,
#  ('area', 'good'): 2,
#  ('fun', 'small'): 2,
#  ('vip', 'good'): 2,
#  ('concert', 'great'): 2,
#  ('lots', 'darn'): 2,
#  ('lots', 'small'): 2,
#  ('lots', 'private'): 2,
#  ('lots', 'pretty'): 2,
#  ('lots', 'sofa'): 2,
#  ('lots', 'mega'): 2,
#  ('lots', 'same'): 2,
#  ('lots', 'great'): 2,
#  ('way', 'small'): 2,
#  ('dancers', 'final'): 2,
#  ('dancers', 'last'): 2,
#  ('dancers', 'old'): 2,
#  ('song', 'old'): 2,
#  ('show', 'ok'): 2,
#  ('show', 'final'): 2,
#  ('woman', 'final'): 2,
#  ('woman', 'last'): 2,
#  ('fan', 'final'): 2,
#  ('fan', 'old'): 2,
#  ('vegas', 'ok'): 2,
#  ('vegas', 'final'): 2,
#  ('vegas', 'last'): 2,
#  ('jlo', 'ok'): 2,
#  ('concert', 'big'): 2,
#  ('thing', 'big'): 2,
#  ('people', 'big'): 2,
#  ('feet', 'bad'): 2,
#  ('fan', 'big'): 2,
#  ('costumes', 'entertaining'): 2,
#  ('dance', 'little'): 2,
#  ('dance', 'further'): 2,
#  ('dance', 'amazing'): 2,
#  ('lo', 'fabulous'): 2,
#  ('lo', 'best'): 2,
#  ('song', 'fabulous'): 2,
#  ('song', 'great'): 2,
#  ('song', 'energetic'): 2,
#  ('show', 'further'): 2,
#  ('show', 'sexy'): 2,
#  ('j', 'fabulous'): 2,
#  ('j', 'first'): 2,
#  ('j', 'best'): 2,
#  ('j', 'sexy'): 2,
#  ('style', 'great'): 2,
#  ('year', 'amazing'): 2,
#  ('front', 'first'): 2,
#  ('front', 'amazing'): 2,
#  ('thing', 'little'): 2,
#  ('thing', 'better'): 2,
#  ('thing', 'sexy'): 2,
#  ('thing', 'great'): 2,
#  ('self', 'first'): 2,
#  ('bucks', 'sexy'): 2,
#  ('bucks', 'great'): 2,
#  ('bucks', 'energetic'): 2,
#  ('vegas', 'fabulous'): 2,
#  ('vegas', 'further'): 2,
#  ('vegas', 'sexy'): 2,
#  ('vegas', 'energetic'): 2,
#  ('kids', 'fabulous'): 2,
#  ('number', 'great'): 2,
#  ('ears', 'great'): 2,
#  ('voice', 'much'): 2,
#  ('', 'much'): 2,
#  ('routines', 'great'): 2,
#  ('motherhood', 'great'): 2,
#  ('sings', 'great'): 2,
#  ('chatter', 'great'): 2,
#  ('pop', 'great'): 2,
#  ('people', 'much'): 2,
#  ('tissue', 'great'): 2,
#  ('point', 'great'): 2,
#  ('sound', 'much'): 2,
#  ('refund', 'great'): 2,
#  ('lighting', 'much'): 2,
#  ('children', 'much'): 2,
#  ('children', 'great'): 2,
#  ('concerts', 'huge'): 2,
#  ('concerts', 'great'): 2,
#  ('performer', 'fantastic'): 2,
#  ('production', 'huge'): 2,
#  ('production', 'great'): 2,
#  ('show', 'fantastic'): 2,
#  ('time', 'fantastic'): 2,
#  ('fan', 'fantastic'): 2,
#  ('energy', 'worth'): 2,
#  ('seats', 'high'): 2,
#  ('seats', 'worth'): 2,
#  ('penny', 'worth'): 2,
#  ('hours', 'high'): 2,
#  ('hours', 'worth'): 2,
#  ('night', 'high'): 2,
#  ('performance', 'much'): 2,
#  ('group', 'good'): 2,
#  ('venue', 'large'): 2,
#  ('concert', 'other'): 2,
#  ('concert', 'amazing'): 2,
#  ('concert', 'many'): 2,
#  ('concert', 'large'): 2,
#  ('songs', 'other'): 2,
#  ('songs', 'much'): 2,
#  ('fan', 'other'): 2,
#  ('fan', 'amazing'): 2,
#  ('seats', 'other'): 2,
#  ('seats', 'large'): 2,
#  ('jlo', 'other'): 2,
#  ('jlo', 'large'): 2,
#  ('vegas', 'other'): 2,
#  ('vegas', 'much'): 2,
#  ('way', 'amazing'): 2,
#  ('way', 'good'): 2,
#  ('stage', 'talented'): 2,
#  ('stage', 'hard'): 2,
#  ('stage', 'more'): 2,
#  ('stadium', 'small'): 2,
#  ('stadium', 'great'): 2,
#  ('stadium', 'good'): 2,
#  ('working', 'cool'): 2,
#  ('nothing', 'great'): 2,
#  ('nothing', 'more'): 2,
#  ('lopez', 'talented'): 2,
#  ('venue', 'hard'): 2,
#  ('venue', 'many'): 2,
#  ('people', 'repetitive'): 2,
#  ('people', 'small'): 2,
#  ('people', 'many'): 2,
#  ('people', 'more'): 2,
#  ('fan', 'most'): 2,
#  ('fan', 'talented'): 2,
#  ('fan', 'better'): 2,
#  ('fan', 'cool'): 2,
#  ('fan', 'hard'): 2,
#  ('woman', 'talented'): 2,
#  ('woman', 'good'): 2,
#  ('section', 'more'): 2,
#  ('section', 'good'): 2,
#  ('review', 'great'): 2,
#  ('review', 'more'): 2,
#  ('seats', 'repetitive'): 2,
#  ('seats', 'talented'): 2,
#  ('seats', 'many'): 2,
#  ('filler', 'bad'): 2,
#  ('filler', 'many'): 2,
#  ('jennifer', 'talented'): 2,
#  ('foot', 'bad'): 2,
#  ('foot', 'small'): 2,
#  ('jlo', 'back'): 2,
#  ('jlo', 'soo'): 2,
#  ('jlo', 'reseated'): 2,
#  ('jlo', 'major'): 2,
#  ('jlo', ''): 2,
#  ('jlo', 'super'): 2,
#  ('jlo', 'sensory'): 2,
#  ('jlo', 'like'): 2,
#  ('jlo', 'insulting'): 2,
#  ('jlo', 'ridiculous'): 2,
#  ('jlo', 'casual'): 2,
#  ('jlo', 'most'): 2,
#  ('jlo', 'best'): 2,
#  ('jlo', 'fanatic'): 2,
#  ('jlo', 'smaller'): 2,
#  ('jlo', 'small'): 2,
#  ('jlo', 'leg'): 2,
#  ('jlo', 'dead'): 2,
#  ('jlo', 'review'): 2,
#  ('jlo', 'obvious'): 2,
#  ('jlo', 'coach'): 2,
#  ('jlo', 'jlo'): 2,
#  ('jlo', 'decent'): 2,
#  ('jlo', 'laughable'): 2,
#  ('show', 'hard'): 2,
#  ('front', 'best'): 2,
#  ('front', 'bad'): 2,
#  ('front', 'small'): 2,
#  ('money', 'bad'): 2,
#  ('money', 'hard'): 2,
#  ('money', 'many'): 2,
#  ('money', 'more'): 2,
#  ('money', 'good'): 2,
#  ('seating', 'small'): 2,
#  ('seating', 'more'): 2,
#  ('seating', 'good'): 2,
#  ('etc', 'cool'): 2,
#  ('etc', 'more'): 2,
#  ('etc', 'good'): 2,
#  ('music', 'hard'): 2,
#  ('changes', 'bad'): 2,
#  ('changes', 'small'): 2,
#  ('changes', 'many'): 2,
#  ('price', 'bad'): 2,
#  ('price', 'many'): 2,
#  ('experience', 'small'): 2,
#  ('experience', 'more'): 2,
#  ('stars', 'great'): 2,
#  ('stars', 'good'): 2,
#  ('room', 'small'): 2,
#  ('room', 'great'): 2,
#  ('room', 'good'): 2,
#  ('lot', 'best'): 2,
#  ('vegas', 'bad'): 2,
#  ('vegas', 'better'): 2,
#  ('rows', 'talented'): 2,
#  ('rows', 'great'): 2,
#  ('rows', 'more'): 2,
#  ('hollywood', 'many'): 2,
#  ('hollywood', 'good'): 2,
#  ('audience', 'talented'): 2,
#  ('audience', 'bad'): 2,
#  ('audience', 'small'): 2,
#  ('audience', 'great'): 2,
#  ('audience', 'many'): 2,
#  ('audience', 'good'): 2,
#  ('tickets', 'small'): 2,
#  ('tickets', 'great'): 2,
#  ('tickets', 'hard'): 2,
#  ('tickets', 'more'): 2,
#  ('planet', 'talented'): 2,
#  ('planet', 'great'): 2,
#  ('planet', 'many'): 2,
#  ('center', 'hard'): 2,
#  ('center', 'good'): 2,
#  ('', 'repetitive'): 2,
#  ('', 'talented'): 2,
#  ('', 'good'): 2,
#  ('choreography', 'bad'): 2,
#  ('choreography', 'small'): 2,
#  ('choreography', 'more'): 2,
#  ('pure', 'great'): 2,
#  ('pure', 'more'): 2,
#  ('dancing', 'best'): 2,
#  ('dancing', 'talented'): 2,
#  ('dancing', 'better'): 2,
#  ('songs', 'repetitive'): 2,
#  ('songs', 'bad'): 2,
#  ('songs', 'cool'): 2,
#  ('songs', 'good'): 2,
#  ('time', 'bad'): 2,
#  ('time', 'hard'): 2,
#  ('time', 'many'): 2,
#  ('set', 'great'): 2,
#  ('music', 'able'): 2,
#  ('music', 'better'): 2,
#  ('music', 'cool'): 2,
#  ('seat', 'better'): 2,
#  ('jlo', 'overall'): 2,
#  ('jlo', 'right'): 2,
#  ('changes', 'able'): 2,
#  ('changes', 'better'): 2,
#  ('changes', 'overall'): 2,
#  ('changes', 'cool'): 2,
#  ('changes', 'same'): 2,
#  ('one', 'good'): 2,
#  ('everyone', 'good'): 2,
#  ('price', 'able'): 2,
#  ('price', 'better'): 2,
#  ('price', 'cool'): 2,
#  ('price', 'good'): 2,
#  ('price', 'great'): 2,
#  ('experience', 'able'): 2,
#  ('experience', 'better'): 2,
#  ('experience', 'cool'): 2,
#  ('experience', 'same'): 2,
#  ('start', 'right'): 2,
#  ('start', 'cool'): 2,
#  ('times', 'able'): 2,
#  ('times', 'right'): 2,
#  ('times', 'good'): 2,
#  ('anything', 'able'): 2,
#  ('anything', 'good'): 2,
#  ('anything', 'great'): 2,
#  ('show', 'overall'): 2,
#  ('show', 'right'): 2,
#  ('show', 'same'): 2,
#  ('kind', 'better'): 2,
#  ('kind', 'cool'): 2,
#  ('kind', 'good'): 2,
#  ('kind', 'great'): 2,
#  ('costumes', 'able'): 2,
#  ('costumes', 'good'): 2,
#  ('front', 'right'): 2,
#  ('front', 'cool'): 2,
#  ('front', 'good'): 2,
#  ('people', 'right'): 2,
#  ('people', 'cool'): 2,
#  ('lights', 'cool'): 2,
#  ('lot', 'overall'): 2,
#  ('lot', 'cool'): 2,
#  ('seats', 'better'): 2,
#  ('seats', 'cool'): 2,
#  ('time', 'better'): 2,
#  ('security', 'able'): 2,
#  ('security', 'right'): 2,
#  ('security', 'good'): 2,
#  ('time', 'best'): 2,
#  ('stage', 'high'): 2,
#  ('stage', 'most'): 2,
#  ('stage', 'super'): 2,
#  ('changes', 'most'): 2,
#  ('changes', 'super'): 2,
#  ('ton', 'most'): 2,
#  ('ton', 'super'): 2,
#  ('ton', 'great'): 2,
#  ('outfit', 'most'): 2,
#  ('outfit', 'super'): 2,
#  ('outfit', 'great'): 2,
#  ('hits', 'high'): 2,
#  ('show', 'special'): 2,
#  ('show', 'super'): 2,
#  ('great', 'high'): 2,
#  ('great', 'great'): 2,
#  ('confetti', 'great'): 2,
#  ('lol', 'beautiful'): 2,
#  ('time', 'super'): 2,
#  ('theater', 'great'): 2,
#  ('effects', 'special'): 2,
#  ('music', 'little'): 2,
#  ('music', 'first'): 2,
#  ('music', 'beautiful'): 2,
#  ('music', 'many'): 2,
#  ('music', 'full'): 2,
#  ('minutes', 'many'): 2,
#  ('minutes', 'more'): 2,
#  ('minutes', 'full'): 2,
#  ('minutes', 'great'): 2,
#  ('everyone', 'first'): 2,
#  ('everyone', 'many'): 2,
#  ('everyone', 'more'): 2,
#  ('seat', 'little'): 2,
#  ('seat', 'first'): 2,
#  ('seat', 'amazing'): 2,
#  ('times', 'old'): 2,
#  ('times', 'high'): 2,
#  ('times', 'first'): 2,
#  ('times', 'amazing'): 2,
#  ('times', 'more'): 2,
#  ('times', 'great'): 2,
#  ('britney', 'awesome'): 2,
#  ('britney', 'first'): 2,
#  ('britney', 'great'): 2,
#  ('show', 'awesome'): 2,
#  ('show', 'full'): 2,
#  ('jlo', 'little'): 2,
#  ('las', 'many'): 2,
#  ('las', 'more'): 2,
#  ('las', 'full'): 2,
#  ('las', 'great'): 2,
#  ('respect', 'little'): 2,
#  ('respect', 'first'): 2,
#  ('respect', 'amazing'): 2,
#  ('respect', 'great'): 2,
#  ('class', 'old'): 2,
#  ('songs', 'old'): 2,
#  ('songs', 'beautiful'): 2,
#  ('songs', 'amazing'): 2,
#  ('songs', 'more'): 2,
#  ('songs', 'full'): 2,
#  ('lot', 'first'): 2,
#  ('lot', 'amazing'): 2,
#  ('lot', 'many'): 2,
#  ('lot', 'more'): 2,
#  ('lot', 'full'): 2,
#  ('vegas', 'little'): 2,
#  ('vegas', 'old'): 2,
#  ('vegas', 'beautiful'): 2,
#  ('vegas', 'full'): 2,
#  ('opinion', 'little'): 2,
#  ('opinion', 'beautiful'): 2,
#  ('opinion', 'amazing'): 2,
#  ('opinion', 'more'): 2,
#  ('opinion', 'great'): 2,
#  ('husband', 'old'): 2,
#  ('husband', 'high'): 2,
#  ('husband', 'amazing'): 2}

# %%
nouns = set()
top5_pairs = []

for pair in list(repeated.keys()):
    if len(top5_pairs) == 5:
        break
    if pair[0] not in nouns:
        top5_pairs.append(pair)
        nouns.add(pair[0])
        
top5_pairs
# Out:
# [('show', 'great'),
#  ('jlo', 'great'),
#  ('seats', 'good'),
#  ('fan', 'huge'),
#  ('time', 'great')]
